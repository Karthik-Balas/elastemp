# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd

# %%
df_expt = pd.read_csv('diamond_thermal.csv')

# %%
df = pd.read_csv('results_dir/volume_temp.txt',sep='\t')

# %%
df
# Out:
#      temperature    Volume_T  Volume_0  Volume_thermal_expansion  \
# 0             0.0  46.124130  45.64129              0.000000e+00
# 1             2.0  46.124130  45.64129              0.000000e+00
# 2             4.0  46.124130  45.64129              5.858969e-10
# 3             6.0  46.124130  45.64129             -8.401848e-10
# 4             8.0  46.124130  45.64129              5.324415e-10
# ..            ...        ...       ...                       ...
# 496         992.0  46.457180  45.64129              1.363182e-05
# 497         994.0  46.458447  45.64129              1.364345e-05
# 498         996.0  46.459716  45.64129              1.365562e-05
# 499         998.0  46.460986  45.64129              1.366481e-05
# 500        1000.0  46.462256  45.64129              1.367433e-05
#
#      Linear_thermal_expansion    Cv_calc  Linear_expansion_factor  \
# 0                0.000000e+00   0.000000                 1.000000
# ...

# %%
temp = df['temperature ']
thermal_exp = df['Linear_thermal_expansion']*1e6

# %%
plt.plot(df_expt['temp'],df_expt['thermal_exp'],'bv')
plt.plot(temp,thermal_exp,'r')
plt.show()

# %%
def getconst(C0,C1,T):
    return C0+C1*(T**2-300**2)

# %%
c11_expt_arr=[]
c12_expt_arr=[]
c44_expt_arr=[]
B_expt_arr=[]
temp_expt_arr=[]

# %%
for i in range(0,1050,100):
    temp_expt_arr.append(i)
    c11_expt_arr.append(getconst(1080.4,-29*1e-6,i))
    c12_expt_arr.append(getconst(127,-3*1e-6,i))
    c44_expt_arr.append(getconst(576.6,-22*1e-6,i))
    B_expt_arr.append(getconst(444.8,-1.2e-5,i))

# %%
df = pd.read_csv('results_dir/elastic_constants_temp_adiabatic.csv')
df2 = pd.read_csv('results_dir/moduli_temp_adiabatic.csv',sep='\t')

# %%
df2
# Out:
#           T           K         Eh        Gh        hc      nu
# 0       0.0  440.884000  1162.2373  548.3426  100.3220  0.0708
# 1       2.0  440.844418  1162.1234  548.2870  100.3158  0.0708
# 2       4.0  440.804984  1162.0097  548.2313  100.3097  0.0708
# 3       6.0  440.765334  1161.8958  548.1757  100.3036  0.0708
# 4       8.0  440.725689  1161.7820  548.1201  100.2974  0.0708
# ..      ...         ...        ...       ...       ...     ...
# 496   992.0  426.848696  1110.0024  520.7572   95.0173  0.0776
# 497   994.0  426.825445  1109.9006  520.7016   95.0018  0.0776
# 498   996.0  426.802677  1109.7993  520.6460   94.9956  0.0776
# 499   998.0  426.777488  1109.6962  520.5904   94.9801  0.0776
# 500  1000.0  426.752601  1109.5932  520.5348   94.9740  0.0776
#
# [501 rows x 6 columns]

# %%
df
# Out:
#        temp          c11         c12         c13  c14  c15  c16         c21  \
# 0       0.0  1054.086000  134.283000  134.283000  0.0  0.0  0.0  134.283000
# 1       2.0  1053.990223  134.271516  134.271516  0.0  0.0  0.0  134.271516
# 2       4.0  1053.894593  134.260179  134.260179  0.0  0.0  0.0  134.260179
# 3       6.0  1053.798748  134.248628  134.248628  0.0  0.0  0.0  134.248628
# 4       8.0  1053.702907  134.237080  134.237080  0.0  0.0  0.0  134.237080
# ..      ...          ...         ...         ...  ...  ...  ...         ...
# 496   992.0  1012.177722  134.184182  134.184182  0.0  0.0  0.0  134.184182
# 497   994.0  1012.098276  134.189030  134.189030  0.0  0.0  0.0  134.189030
# 498   996.0  1012.019313  134.194359  134.194359  0.0  0.0  0.0  134.194359
# 499   998.0  1011.937928  134.197268  134.197268  0.0  0.0  0.0  134.197268
# 500  1000.0  1011.856845  134.200479  134.200479  0.0  0.0  0.0  134.200479
#
# ...

# %%
temp = df['temp']
c11 = df['c11']
c12 = df['c12']
c44 = df['c44']
B = df2['K']

# %%
plt.plot(temp_expt_arr,B_expt_arr,'gv')
plt.plot(temp,B,'r')
plt.plot(temp_expt_arr,c11_expt_arr,'gv')
plt.plot(temp,c11.values,'r')
plt.plot(temp_expt_arr,c12_expt_arr,'gv')
plt.plot(temp,c12.values,'r')
plt.plot(temp_expt_arr,c44_expt_arr,'gv')
plt.plot(temp,c44.values,'r')

plt.show()

# %%
c11_exp_arr_TiN2,t_arr_TiN = getc(611,438)
c44_exp_arr_TiN2,t_arr_TiN = getc(160,135)
c12_exp_arr_TiN = [135,126,124,120]
B_exp_arr_TiN = [295,285,275,260]
T_exp_arr_TiN = [0,300,600,900]

# %%
c44_exp_arr_TiN2
# Out:
# [160.0,
#  155.83333333333334,
#  151.66666666666666,
#  147.5,
#  143.33333333333334,
#  139.16666666666666,
#  135.0]

# %%
c11_exp_arr_TiN = [611.0, 582.1666666666666,  553.3333333333334,  524.5]
c44_exp_arr_TiN = [160.0,  155.83333333333334,  151.66666666666666, 147.5]

# %%
df_TiN_mod = pd.read_csv('../TiN_v2/results_dir/moduli_temp_adiabatic.csv',sep='\t')

# %%
c11_TiN = df_TiN_ad['c11']
c12_TiN = df_TiN_ad['c12']
c44_TiN = df_TiN_ad['c44']
B_TiN = df_TiN_mod['K']
t_TiN = df_TiN_ad['temp']

# %%
font = {
        'family' : 'Arial',
        'weight' : 'bold',
        'size'   : 12}

plt.rc('font', **font)
plt.rcParams['axes.linewidth'] = 2 #set the value globally

fig, ax = plt.subplots(2,2,figsize=(10,8),dpi=300, sharex=True)
fig.subplots_adjust(hspace=0.2)
ax[0,0].plot(df_expt['temp'],df_expt['thermal_exp'],'bv')
ax[0,0].plot(temp,thermal_exp,'r',lw=3)

ax[0,1].plot(t,a,'r',lw=3)

ax[1,0].plot(temp_expt_arr,c11_expt_arr,'g*')
ax[1,0].plot(temp,c11.values,'r',lw=3)

ax[1,0].plot(temp_expt_arr,c44_expt_arr,'gs')
ax[1,0].plot(temp,c44.values,color='orange',lw=3)

ax[1,0].plot(temp_expt_arr,c12_expt_arr,'go')
ax[1,0].plot(temp,c12.values,color='brown',lw=3)

ax[1,0].plot(temp_expt_arr,B_expt_arr,'gv')
ax[1,0].plot(temp,B.values,'b',lw=3)


ax[1,1].plot(T_exp_arr_TiN,c11_exp_arr_TiN,'g*')
ax[1,1].plot(t_TiN ,c11_TiN,'r',lw=3)


ax[1,1].plot(T_exp_arr_TiN,c12_exp_arr_TiN,'go')
ax[1,1].plot(t_TiN ,c12_TiN,color='brown',lw=3)

ax[1,1].plot(T_exp_arr_TiN,c44_exp_arr_TiN,'gs')
ax[1,1].plot(t_TiN ,c44_TiN,color='orange',lw=3)

ax[1,1].plot(T_exp_arr_TiN,B_exp_arr_TiN,'gv')
ax[1,1].plot(t_TiN ,B_TiN,color='blue',lw=3)

#ax[1,1].plot(t_arr_TiN,c44_expt_arr,'gs')
#ax[1,1].plot(temp,c44.values,color='orange',lw=3)

#ax[1,1].plot(t_arr_TiN,c12_expt_arr,'gs')
#ax[1,1].plot(temp,c12.values,color='brown',lw=3)

#ax[1,1].plot(t_arr_TiN,B_expt_arr,'gs')
#ax[1,1].plot(temp,B.values,'b',lw=3)


ax[1,0].text(0,200,'$C_{12}$',color='brown')
ax[1,0].text(0,350,'$B$',color='blue')
ax[1,0].text(0,650,'$C_{44}$',color='orange')
ax[1,0].text(0,900,'$C_{11}$',color='red')



ax[1,1].text(200,200,'$C_{12}$',color='brown')
ax[1,1].text(0,350,'$B$',color='blue')
ax[1,1].text(0,200,'$C_{44}$',color='orange')
ax[1,1].text(200,650,'$C_{11}$',color='red')

ax[0,0].text(-40, 5.25, '(a)', fontsize=14, fontweight='bold', va='top', ha='right')
ax[0,0].text(400, 4, 'Diamond', fontsize=14, fontweight='bold', va='top', ha='right')

ax[0,1].text(-40, 16.25, '(c)', fontsize=14, fontweight='bold', va='top', ha='right')
ax[1,0].text(-40, 1250, '(b)', fontsize=14, fontweight='bold', va='top', ha='right')
ax[0,1].text(600, 4, 'TiN', fontsize=14, fontweight='bold', va='top', ha='right')

ax[1,1].text(-40, 750, '(d)', fontsize=14, fontweight='bold', va='top', ha='right')

ax[1,0].set_xlabel('Temperature (K)',fontdict=dict(weight='bold'))
ax[1,1].set_xlabel('Temperature (K)',fontdict=dict(weight='bold'))
ax[1,0].set_ylabel('Elastic constant (GPa)',fontdict=dict(weight='bold'))
ax[0,0].set_ylabel(r' $\alpha$ * 1e6 (1/K)',fontdict=dict(weight='bold'))


plt.savefig('diamond_TiN_elastic_constants.png')

#plt.savefig('diamond_elastic_constants.png')
'''
axs[0,0].plot(df_expt['temp'],df_expt['c11']*100,'g*')
axs[0,0].plot(df_expt2['temp'],df_expt2['c11']*10,'bv')
axs[0,0].plot(temp,c11,'r',lw=3)
axs[0,0].plot(temp,c11_t,color='brown',linestyle='--',lw=3)
axs[0,1].plot(df_expt['temp'],df_expt['c12']*100,'g*')
axs[0,1].plot(df_expt2['temp'],df_expt2['c12']*10,'bv')
axs[0,1].plot(temp,c12,'r',lw=3)
axs[0,1].plot(temp,c12_t,color='brown',linestyle='--',lw=3)
axs[1,0].plot(df_expt['temp'],df_expt['c44']*100,'g*')
axs[1,0].plot(df_expt2['temp'].values,df_expt2['c44'].values*10,'bv')
axs[1,0].plot(temp,c44,'r',lw=3)
axs[1,0].plot(temp,c44_t,color='brown',linestyle='--',lw=3)
axs[1,1].plot(df_expt['temp'],a_arr,'g*')
axs[1,1].plot(df_expt2['temp'],df_expt2['B']*10,'bv')
axs[1,1].plot(temp,K,'r',lw=3)
axs[1,1].plot(temp,K_t,color='brown',linestyle='--',lw=3)
axs[0,0].set_ylabel('$C_{11}$ (GPa)',fontdict=dict(weight='bold'))
axs[0,1].set_ylabel('$C_{12}$ (GPa)',fontdict=dict(weight='bold'))
axs[1,0].set_ylabel('$C_{44}$ (GPa)',fontdict=dict(weight='bold'))
axs[1,1].set_ylabel('$B$ (GPa)',fontdict=dict(weight='bold'))
axs[1,0].set_xlabel('Temperature (K)',fontdict=dict(weight='bold'))
axs[1,1].set_xlabel('Temperature (K)',fontdict=dict(weight='bold'))
axs[1,0].set_yticks([15,20,25,30,35])
axs[1,1].set_yticks([50,60,70,80,90])
axs[0,0].text(-0.1, 130, '(a)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
axs[0,1].text(-0.1, 75.5, '(b)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
axs[1,0].text(-0.1, 37, '(c)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
axs[1,1].text(-0.1, 94, '(d)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
#ax1.text(0.02,-3.84,'600 K',color='blue')
#ax1.text(0.0,-4.04,'900 K',color='blue')

'''
plt.show()

# %%
font = {
        'family' : 'Arial',
        'weight' : 'bold',
        'size'   : 12}

plt.rc('font', **font)
plt.rcParams['axes.linewidth'] = 2 #set the value globally

fig, axs = plt.subplots(2,2,figsize=(10,8),dpi=300, sharex=True,)


axs[0,0].plot(df_expt['temp'],df_expt['c11']*100,'g*')
axs[0,0].plot(df_expt2['temp'],df_expt2['c11']*10,'bv')
axs[0,0].plot(temp,c11,'r',lw=3)
axs[0,0].plot(temp,c11_t,color='brown',linestyle='--',lw=3)
axs[0,1].plot(df_expt['temp'],df_expt['c12']*100,'g*')
axs[0,1].plot(df_expt2['temp'],df_expt2['c12']*10,'bv')
axs[0,1].plot(temp,c12,'r',lw=3)
axs[0,1].plot(temp,c12_t,color='brown',linestyle='--',lw=3)
axs[1,0].plot(df_expt['temp'],df_expt['c44']*100,'g*')
axs[1,0].plot(df_expt2['temp'].values,df_expt2['c44'].values*10,'bv')
axs[1,0].plot(temp,c44,'r',lw=3)
axs[1,0].plot(temp,c44_t,color='brown',linestyle='--',lw=3)
axs[1,1].plot(df_expt['temp'],a_arr,'g*')
axs[1,1].plot(df_expt2['temp'],df_expt2['B']*10,'bv')
axs[1,1].plot(temp,K,'r',lw=3)
axs[1,1].plot(temp,K_t,color='brown',linestyle='--',lw=3)
axs[0,0].set_ylabel('$C_{11}$ (GPa)',fontdict=dict(weight='bold'))
axs[0,1].set_ylabel('$C_{12}$ (GPa)',fontdict=dict(weight='bold'))
axs[1,0].set_ylabel('$C_{44}$ (GPa)',fontdict=dict(weight='bold'))
axs[1,1].set_ylabel('$B$ (GPa)',fontdict=dict(weight='bold'))
axs[1,0].set_xlabel('Temperature (K)',fontdict=dict(weight='bold'))
axs[1,1].set_xlabel('Temperature (K)',fontdict=dict(weight='bold'))
axs[1,0].set_yticks([15,20,25,30,35])
axs[1,1].set_yticks([50,60,70,80,90])
axs[0,0].text(-0.1, 130, '(a)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
axs[0,1].text(-0.1, 75.5, '(b)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
axs[1,0].text(-0.1, 37, '(c)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
axs[1,1].text(-0.1, 94, '(d)', 
      fontsize=16, fontweight='bold', va='top', ha='right')
#ax1.text(0.02,-3.84,'600 K',color='blue')
#ax1.text(0.0,-4.04,'900 K',color='blue')
plt.savefig('diamond_elastic_constants.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-8ab2e97b5462> in <module>
#      10
#      11
# ---> 12 axs[0,0].plot(df_expt['temp'],df_expt['c11']*100,'g*')
#      13 axs[0,0].plot(df_expt2['temp'],df_expt2['c11']*10,'bv')
#      14 axs[0,0].plot(temp,c11,'r',lw=3)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
df_a_TiN = pd.read_csv('../TiN_v2/results_dir/volume_temp.txt',sep='\t')

# %%
t = df_a_TiN['temperature ']
a = df_a_TiN['Linear_thermal_expansion']*1e6

# %%
df_TiN_ad = pd.read_csv('../TiN_v2/results_dir/elastic_constants_temp_adiabatic.csv')

# %%
c11_TiN = df_TiN_ad['c11']
c12_TiN = df_TiN_ad['c12']
c44_TiN = df_TiN_ad['c44']

# %%
plt.plot(t,c11)
plt.show()

# %%
def getc(c0,cf):
    c_arr = []; t_arr=[]
    for i in range(7):
        c_val = c0 + (cf-c0)*i*300/1800
        c_arr.append(c_val)
        t_arr.append(i*300)
    return c_arr,t_arr

# %%
plt.plot(t_arr,c44_exp_arr,'ro')
plt.show()

# %%
plt.plot(t,a)
plt.show()

# %%
df_a_TiN
# Out:
#      temperature    Volume_T   Volume_0  Volume_thermal_expansion  \
# 0             0.0  77.718281  76.593858              0.000000e+00
# 1             2.0  77.718281  76.593858              3.653417e-10
# 2             4.0  77.718281  76.593858             -5.422009e-10
# 3             6.0  77.718281  76.593858              1.649902e-09
# 4             8.0  77.718282  76.593858              4.058299e-09
# ..            ...        ...        ...                       ...
# 496         992.0  79.981907  76.593858              4.234028e-05
# 497         994.0  79.988686  76.593858              4.237726e-05
# 498         996.0  79.995472  76.593858              4.241705e-05
# 499         998.0  80.002264  76.593858              4.245468e-05
# 500        1000.0  80.009063  76.593858              4.249330e-05
#
#      Linear_thermal_expansion    Cv_calc  Linear_expansion_factor  \
# 0                0.000000e+00   0.000000                 1.000000
# ...

# %%
plt.plot(temp_expt_arr,c11_expt_arr,'b')
plt.plot(temp,c11.values,'r')
plt.ylim(900,1200)
plt.show()

# %%
c11
# Out:
# 0      1054.086000
# 1      1053.990223
# 2      1053.894593
# 3      1053.798748
# 4      1053.702907
#           ...
# 496    1012.177722
# 497    1012.098276
# 498    1012.019313
# 499    1011.937928
# 500    1011.856845
# Name: c11, Length: 501, dtype: float64

# %%
import os

# %%
os.getcwd()
# Out:
# '/global/cscratch1/sd/karthb/elastemp_test/v8/diamond'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-181-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import matplotlib.image as mpimg

# %%
fig = plt.figure(figsize=(10, 7))
rows = 3
columns = 1

Image1 = mpimg.imread('deformation-1/deformation-1-strain-curve.png')
Image2 = mpimg.imread('deformation-2/deformation-2-strain-curve.png')
Image3 = mpimg.imread('deformation-3/deformation-3-strain-curve.png')
imgplot1 = plt.imshow(Image1)
imgplot2 = plt.imshow(Image2)
imgplot3 = plt.imshow(Image3)
plt.show()

# %%
def process(filename: str=None) -> None:
    """
    View multiple images stored in files, stacking vertically

    Arguments:
        filename: str - path to filename containing image
    """
    image = mpimg.imread(filename)
    # <something gets done here>
    plt.figure()
    plt.imshow(image)

# %%
process('deformation-1/deformation-1-strain-curve.png')
process('deformation-2/deformation-2-strain-curve.png')
process('deformation-3/deformation-3-strain-curve.png')

# %%
fig = plt.figure(figsize=(14, 10))
plt.subplot(1, 3,1)
image = mpimg.imread('deformation-1/deformation-1-strain-curve.png')
plt.imshow(image)
plt.axis('off')
plt.subplot(1, 3,2)
image = mpimg.imread('deformation-2/deformation-2-strain-curve.png')
plt.imshow(image)
plt.axis('off')
plt.subplot(1, 3,3)
image = mpimg.imread('deformation-3/deformation-3-strain-curve.png')
plt.imshow(image)
plt.axis('off')
plt.savefig('diamond-deformation-energies.png')
plt.show()

# %%
df_vol = pd.read_csv('results_dir/volume_temp.txt',sep='\t')

# %%
df_vol
# Out:
#      temperature    Volume_T  Volume_0  Volume_thermal_expansion  \
# 0             0.0  46.124130  45.64129              0.000000e+00
# 1             2.0  46.124130  45.64129              0.000000e+00
# 2             4.0  46.124130  45.64129              5.858969e-10
# 3             6.0  46.124130  45.64129             -8.401848e-10
# 4             8.0  46.124130  45.64129              5.324415e-10
# ..            ...        ...       ...                       ...
# 496         992.0  46.457180  45.64129              1.363182e-05
# 497         994.0  46.458447  45.64129              1.364345e-05
# 498         996.0  46.459716  45.64129              1.365562e-05
# 499         998.0  46.460986  45.64129              1.366481e-05
# 500        1000.0  46.462256  45.64129              1.367433e-05
#
#      Linear_thermal_expansion    Cv_calc  Linear_expansion_factor  \
# 0                0.000000e+00   0.000000                 1.000000
# ...

# %%
temp = df_vol['temperature ']
lin_exp = df_vol['Linear_expansion_factor']
thermal_exp = df_vol['Linear_thermal_expansion']*1e6
vols = df_vol[' Volume_T'].values

# %%
vols
# Out:
# 0      46.124130
# 1      46.124130
# 2      46.124130
# 3      46.124130
# 4      46.124130
#          ...
# 496    46.457180
# 497    46.458447
# 498    46.459716
# 499    46.460986
# 500    46.462256
# Name:  Volume_T, Length: 501, dtype: float64

# %%
a0 = 3.57
a = [a0*lin_exp[i] for i in range(len(lin_exp))]

# %%
plt.show()

# %%
fig = plt.figure(figsize=(14, 6))
plt.subplot(1, 3,1)
plt.plot(temp,a,'r')
plt.xlabel('Temperature(K)')
plt.ylabel(r'Lattice parameter $\AA$')
plt.subplot(1, 3,2)
plt.plot(temp,vols,'r')
plt.xlabel('Temperature(K)')
plt.ylabel(r'Volume $\AA^3$')
plt.subplot(1, 3,3)
plt.plot(temp,thermal_exp,'r')
plt.xlabel('Temperature(K)')
plt.ylabel(r'$\alpha$ *1e6')
plt.tight_layout()
#plt.savefig('diamond-deformation-energies.png')
plt.show()

# %%
plt.show()

# %%
  
# reading images

Image4 = cv2.imread('Image4.jpg')
  
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1)
plt.axis('off')
plt.title("First")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(Image2)
plt.axis('off')
plt.title("Second")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(Image3)
plt.axis('off')
plt.title("Third")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(Image4)
plt.axis('off')
plt.title("Fourth")
